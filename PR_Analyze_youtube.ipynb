# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
# %matplotlib inline

# %%
youtube = pd.read_csv('USvideos.csv')

# %%
youtube
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# ...

# %%
youtube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
# video_id                  40949 non-null object
# trending_date             40949 non-null object
# title                     40949 non-null object
# channel_title             40949 non-null object
# category_id               40949 non-null int64
# publish_time              40949 non-null object
# tags                      40949 non-null object
# views                     40949 non-null int64
# likes                     40949 non-null int64
# dislikes                  40949 non-null int64
# comment_count             40949 non-null int64
# thumbnail_link            40949 non-null object
# comments_disabled         40949 non-null bool
# ratings_disabled          40949 non-null bool
# video_error_or_removed    40949 non-null bool
# description               40379 non-null object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %%
youtube.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
youtube0 = youtube[youtube['likes'] - youtube['dislikes']  == 0]
youtube0
# Out:
#           video_id trending_date  \
# 192    wRGldR_SQAA      17.14.11
# 1435   Kn5UgGQukYQ      17.21.11
# 1667   Kn5UgGQukYQ      17.22.11
# 1868   _akwfRuL4os      17.23.11
# 1914   Kn5UgGQukYQ      17.23.11
# ...            ...           ...
# 28135  UwbO_xb1-Xo      18.05.04
# 28346  UwbO_xb1-Xo      18.06.04
# 28550  9TUBf6l7FBg      18.14.04
# 28751  9TUBf6l7FBg      18.15.04
# 28955  9TUBf6l7FBg      18.16.04
#
#                                                    title        channel_title  \
# 192                                   Apple Clips sample         Steve Kovach
# 1435   Breaking Bad's Bryan Cranston on Meeting Charl...   hudsonunionsociety
# 1667   Breaking Bad's Bryan Cranston on Meeting Charl...   hudsonunionsociety
# 1868   Highlights of the EA predatory behavior announ...            chris lee
# 1914   Breaking Bad's Bryan Cranston on Meeting Charl...   hudsonunionsociety
# ...                                                  ...                  ...
# ...

# %%
youtube0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181 entries, 192 to 28955
# Data columns (total 16 columns):
# video_id                  181 non-null object
# trending_date             181 non-null object
# title                     181 non-null object
# channel_title             181 non-null object
# category_id               181 non-null int64
# publish_time              181 non-null object
# tags                      181 non-null object
# views                     181 non-null int64
# likes                     181 non-null int64
# dislikes                  181 non-null int64
# comment_count             181 non-null int64
# thumbnail_link            181 non-null object
# comments_disabled         181 non-null bool
# ratings_disabled          181 non-null bool
# video_error_or_removed    181 non-null bool
# description               175 non-null object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 20.3+ KB

# %%
youtube0['delta_like'] = youtube0['likes'] - youtube0['dislikes']
# Out:
# C:\Users\Sabam-Mr\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
youtube0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181 entries, 192 to 28955
# Data columns (total 17 columns):
# video_id                  181 non-null object
# trending_date             181 non-null object
# title                     181 non-null object
# channel_title             181 non-null object
# category_id               181 non-null int64
# publish_time              181 non-null object
# tags                      181 non-null object
# views                     181 non-null int64
# likes                     181 non-null int64
# dislikes                  181 non-null int64
# comment_count             181 non-null int64
# thumbnail_link            181 non-null object
# comments_disabled         181 non-null bool
# ratings_disabled          181 non-null bool
# video_error_or_removed    181 non-null bool
# description               175 non-null object
# delta_like                181 non-null int64
# dtypes: bool(3), int64(6), object(8)
# memory usage: 21.7+ KB

# %%
youtube0.head()
# Out:
#          video_id trending_date  \
# 192   wRGldR_SQAA      17.14.11
# 1435  Kn5UgGQukYQ      17.21.11
# 1667  Kn5UgGQukYQ      17.22.11
# 1868  _akwfRuL4os      17.23.11
# 1914  Kn5UgGQukYQ      17.23.11
#
#                                                   title       channel_title  \
# 192                                  Apple Clips sample        Steve Kovach
# 1435  Breaking Bad's Bryan Cranston on Meeting Charl...  hudsonunionsociety
# 1667  Breaking Bad's Bryan Cranston on Meeting Charl...  hudsonunionsociety
# 1868  Highlights of the EA predatory behavior announ...           chris lee
# 1914  Breaking Bad's Bryan Cranston on Meeting Charl...  hudsonunionsociety
#
#       category_id              publish_time  \
# 192            22  2017-11-09T18:01:04.000Z
# 1435            1  2016-10-14T21:14:51.000Z
# 1667            1  2016-10-14T21:14:51.000Z
# 1868           22  2017-11-21T19:29:03.000Z
# 1914            1  2016-10-14T21:14:51.000Z
#
# ...

# %%
plt.figure(figsize = (8,5))
sns.heatmap(youtube0.corr(), cmap='coolwarm', linewidths = .8, annot=True)

# %%
sns.countplot(data=youtube0, x = 'comments_disabled')

# %%
sns.countplot(data=youtube0, x='ratings_disabled')

# %%
# mencari delta_likes = 0
youtube['delta_likes'] = youtube['likes'] - youtube['dislikes']

# %%
youtube.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
youtube[['likes','dislikes','delta_likes']].head()
# Out:
#     likes  dislikes  delta_likes
# 0   57527      2966        54561
# 1   97185      6146        91039
# 2  146033      5339       140694
# 3   10172       666         9506
# 4  132235      1989       130246

# %%
# Mencari hari
youtube0['publish_day'] = pd.to_datetime(youtube0['publish_time']).dt.day_name()
youtube0['publish_day']
# Out:
# C:\Users\Sabam-Mr\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 192       Thursday
# 1435        Friday
# 1667        Friday
# 1868       Tuesday
# 1914        Friday
#            ...
# 28135    Wednesday
# 28346    Wednesday
# 28550     Thursday
# 28751     Thursday
# 28955     Thursday
# Name: publish_day, Length: 181, dtype: object

# %%
youtube0['publish_day'].value_counts()
# Out:
# Wednesday    45
# Monday       36
# Tuesday      28
# Friday       28
# Sunday       27
# Thursday     11
# Saturday      6
# Name: publish_day, dtype: int64

# %%
youtube0['channel_title'].value_counts()
# Out:
# Kim Kardashian West             13
# Tati                            11
# Famous Celebrities Snaps        10
# Kylie Jenner                    10
# cheeseandjamsandwich             9
# T-Mobile                         8
# Snapchat                         8
# hudsonunionsociety               7
# Dancing On Ice                   7
# Alpha Entertainment              7
# Pac-12 Networks                  6
# Paris Hilton                     6
# LoeyLane                         6
# Slooh                            6
# mariahxlambily                   6
# Voicebot                         5
# TV One                           5
# Caravan Carolyn                  4
# MassMutual                       4
# Sports Lovers n1                 4
# Chris Lee                        4
# DJI                              4
# Define American                  4
# HARRY                            4
# Michelob ULTRA                   4
# Coachella                        3
# jeremiah johnson                 3
# ...

# %%
# Mencari hari
youtube['publish_day'] = pd.to_datetime(youtube['publish_time']).dt.day_name()
youtube['publish_day']
# Out:
# 0          Monday
# 1          Monday
# 2          Sunday
# 3          Monday
# 4          Sunday
#            ...
# 40944      Friday
# 40945      Friday
# 40946      Friday
# 40947    Thursday
# 40948    Thursday
# Name: publish_day, Length: 40949, dtype: object

# %%
def ganti_tanggal_trending(cols):
    year = cols[0:2]
    month = cols[6:8]
    day = cols[3:5]
    cols = '20'+'{}.{}.{}'.format(year,month,day)
    return cols

youtube['trending_date'] =youtube['trending_date'].apply(ganti_tanggal_trending)

# %%
youtube['trending_date'] = pd.to_datetime(youtube['trending_date'], utc='none')
youtube['publish_time'] = pd.to_datetime(youtube['publish_time'])

# %%
youtube['trending_gap'] = youtube['trending_date'] - youtube['publish_time']

# %%
plt.figure(figsize=(8,8))
sns.distplot(youtube['trending_gap'].dt.days, hist = True, color='r')
plt.title('Trending Gap')
# Out:
# Text(0.5, 1.0, 'Trending Gap')

# %%
youtube.head()
# Out:
#       video_id             trending_date  \
# 0  2kyS6SvSYSE 2017-11-14 00:00:00+00:00
# 1  1ZAPwfrtAFY 2017-11-14 00:00:00+00:00
# 2  5qpjK5DgCt4 2017-11-14 00:00:00+00:00
# 3  puqaWrEC7tY 2017-11-14 00:00:00+00:00
# 4  d380meD0W0M 2017-11-14 00:00:00+00:00
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22 2017-11-13 17:13:01+00:00
# 1           24 2017-11-13 07:30:00+00:00
# 2           23 2017-11-12 19:05:24+00:00
# 3           24 2017-11-13 11:00:04+00:00
# 4           24 2017-11-12 18:01:41+00:00
#
# ...

# %%
import json
youtube0['category_id'] = youtube0['category_id'].astype(str)
# Out:
# C:\Users\Sabam-Mr\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# mencari varibel di category_id
category_str = pd.read_json('GB_category_id.json')

# %%
category_film = {}
for i in category_str['items']:
    category_film[i['id']] = i['snippet']['title']

# %%
youtube0.insert(4, 'category', youtube0['category_id'].map(category_film))

# %%
youtube0.head()
# Out:
#          video_id trending_date  \
# 192   wRGldR_SQAA      17.14.11
# 1435  Kn5UgGQukYQ      17.21.11
# 1667  Kn5UgGQukYQ      17.22.11
# 1868  _akwfRuL4os      17.23.11
# 1914  Kn5UgGQukYQ      17.23.11
#
#                                                   title       channel_title  \
# 192                                  Apple Clips sample        Steve Kovach
# 1435  Breaking Bad's Bryan Cranston on Meeting Charl...  hudsonunionsociety
# 1667  Breaking Bad's Bryan Cranston on Meeting Charl...  hudsonunionsociety
# 1868  Highlights of the EA predatory behavior announ...           chris lee
# 1914  Breaking Bad's Bryan Cranston on Meeting Charl...  hudsonunionsociety
#
#               category category_id              publish_time  \
# 192     People & Blogs          22  2017-11-09T18:01:04.000Z
# 1435  Film & Animation           1  2016-10-14T21:14:51.000Z
# 1667  Film & Animation           1  2016-10-14T21:14:51.000Z
# 1868    People & Blogs          22  2017-11-21T19:29:03.000Z
# ...

# %%
korelasi = youtube0.corr(method='pearson')
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(korelasi, annot= True, linewidths = .8, fmt='.3f', ax = ax)
plt.show()

# %% [markdown]
# # Menentukkan sample yang ingin di analisis

# %%
sample = youtube0[['ratings_disabled','comments_disabled','channel_title','publish_day','category']]
sample.describe()
# Out:
#        ratings_disabled comments_disabled        channel_title publish_day  \
# count               181               181                  181         181
# unique                2                 2                   38           7
# top                True              True  Kim Kardashian West   Wednesday
# freq                169               106                   13          45
#
#               category
# count              177
# unique              11
# top     People & Blogs
# freq                43

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181 entries, 192 to 28955
# Data columns (total 5 columns):
# ratings_disabled     181 non-null bool
# comments_disabled    181 non-null bool
# channel_title        181 non-null object
# publish_day          181 non-null object
# category             177 non-null object
# dtypes: bool(2), object(3)
# memory usage: 11.0+ KB

# %%
sample = youtube0[['ratings_disabled','comments_disabled','channel_title','publish_day','category','views']]
plt.figure(figsize=(13,8))
sns.countplot(y='publish_day', hue="category", data=sample)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
# Grafik di atas menunjukkan jenis category video yang di upload setiap harinya

# %%
sample = youtube0[['ratings_disabled','comments_disabled','channel_title','publish_day','category','views']]
plt.figure(figsize=(8,15))
vis = sns.swarmplot(x='views',y = 'channel_title', hue = 'ratings_disabled', data=sample)
vis.legend_.remove()
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Grafik di atas menunjukkan perbandingan channel title dengan views, berdasarkan value ratings disabled

# %%
sample = youtube0[['ratings_disabled','comments_disabled','channel_title','publish_day','category','views']]
plt.figure(figsize=(10,15))
sns.catplot(x='ratings_disabled',col ='publish_day',data=sample, kind='count',height=5, aspect=.7)
sns.catplot(x='comments_disabled',col ='publish_day',data=sample, kind='count',height=5, aspect=.7)

plt.show()

# %%
# Berdasarkan grafik di atas menunjukkan bahwa video deltalikes 0 memilih untuk men disabled ratings dan comments video mereka

# %%
# Mencari jumlah category yang paling banyak ditonton
sample = youtube0[['ratings_disabled','comments_disabled','channel_title','publish_day','category','views']]
plt.figure(figsize=(12,6))
g1 = sns.countplot(sample['category'], data=sample, palette='Set1', order=sample['category'].value_counts().index)
g1.set_xticklabels(g1.get_xticklabels(), rotation = 45, ha='right')
g1.set_title('count of video categories', fontsize = 15)
g1.set_xlabel('', fontsize=12)
g1.set_ylabel('count', fontsize=12)
plt.subplots_adjust(wspace=0.9, hspace=0.9, top=0.9)
plt.show()

# %%
youtube0.head()
# Out:
#          video_id trending_date  \
# 192   wRGldR_SQAA      17.14.11
# 1435  Kn5UgGQukYQ      17.21.11
# 1667  Kn5UgGQukYQ      17.22.11
# 1868  _akwfRuL4os      17.23.11
# 1914  Kn5UgGQukYQ      17.23.11
#
#                                                   title       channel_title  \
# 192                                  Apple Clips sample        Steve Kovach
# 1435  Breaking Bad's Bryan Cranston on Meeting Charl...  hudsonunionsociety
# 1667  Breaking Bad's Bryan Cranston on Meeting Charl...  hudsonunionsociety
# 1868  Highlights of the EA predatory behavior announ...           chris lee
# 1914  Breaking Bad's Bryan Cranston on Meeting Charl...  hudsonunionsociety
#
#               category category_id              publish_time  \
# 192     People & Blogs          22  2017-11-09T18:01:04.000Z
# 1435  Film & Animation           1  2016-10-14T21:14:51.000Z
# 1667  Film & Animation           1  2016-10-14T21:14:51.000Z
# 1868    People & Blogs          22  2017-11-21T19:29:03.000Z
# ...

# %%
youtube['publish_time_real'] = pd.to_datetime(youtube['publish_time'])

# %%
youtube.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
import statsmodels.api as sm
import pylab

sm.qqplot(youtube[youtube['trending_gap'].dt.days <= 5]['views'],line='45')
plt.title('Less than 5 no log')

sm.qqplot(np.log(youtube[youtube['trending_gap'].dt.days <= 5]['views']),line='45')
plt.title('less than 5 log')
pylab.show()

# %%
from scipy.stats import shapiro,normaltest, anderson
def trynormal(data):
    result={'Anderson':{i:j for i,j in zip(anderson(data)[2],anderson(data)[1])}, 'shapiro' : shapiro(data)[1],'k^2' : normaltest(data)[1]}
    result['Anderson']['stat'] = anderson(data)[0]
    return result

# %%
anderson(youtube[youtube['trending_gap'].dt.days <= 5]['views'])
# Out:
# AndersonResult(statistic=4926.30720475698, critical_values=array([0.576, 0.656, 0.787, 0.918, 1.092]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %%
trynormal(youtube[youtube['trending_gap'].dt.days <=5]['views'])
# Out:
# C:\Users\Sabam-Mr\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1660: UserWarning:
#
# p-value may not be accurate for N > 5000.
# {'Anderson': {15.0: 0.576,
#   10.0: 0.656,
#   5.0: 0.787,
#   2.5: 0.918,
#   1.0: 1.092,
#   'stat': 4926.30720475698},
#  'shapiro': 0.0,
#  'k^2': 0.0}
