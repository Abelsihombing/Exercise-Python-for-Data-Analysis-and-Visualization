# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
import random
def dice_roll(dice_sum, roll):
    dadu = [1,2,3,4,5,6]
    a = []
    b = []
    x = 0
    for j in range(roll):
        for i in range(dice_sum):
            x += np.random.choice(dadu)
            b.append(x)
            x = 0
        a.append(np.mean(b))
        b = []
#     return a
    sns.distplot(a)
dice_roll(2,1000)

# %%
import random
from matplotlib.pyplot import show
def dice_roll(n, time):
    hasil = []
    dadu = [1,2,3,4,5,6]
    result = 0
    for i in range(time):
        for i in range(n):
            result += np.random.choice(dadu)
        hasil.append(result)
        result = 0
    plt
    sns.distplot(hasil)
    plt.xticks(range(n, (n*6)+1))
# def dice_roll(n, time):
#     ploting = []
#     for i in range(time):
#         dadu = []
#         for j in range(n):
#             dadu.append(np.random.randint(1,7))
#         ploting.append(sum(dadu))
#         plt.figure(figsize=(10,8))
        
#         plt.xticks(range(n,(n*6)+1))
#     sns.distplot(ploting)
# dice_roll(1,1000)

# %%
dice_roll(1,10000)
